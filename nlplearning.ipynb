# %% [markdown]
# ## NLP Complete Learning

# %%
print("hi")
# Out:
# hi

# %%
import numpy as np
import sklearn
import pandas as pd

# %%
df=pd.read_csv("Urban Air Quality and Health Impact Dataset.csv")
df2=pd.read_csv('Sheet_1.csv')
df2
# Out:
#     response_id        class  \
# 0    response_1  not_flagged
# 1    response_2      flagged
# 2    response_3      flagged
# 3    response_4  not_flagged
# 4    response_5  not_flagged
# ..          ...          ...
# 75  response_76  not_flagged
# 76  response_77      flagged
# 77  response_78  not_flagged
# 78  response_79      flagged
# 79  response_80  not_flagged
#
#                                         response_text Unnamed: 3  Unnamed: 4  \
# 0               I try and avoid this sort of conflict        NaN         NaN
# 1   Had a friend open up to me about his mental ad...        NaN         NaN
# 2   I saved a girl from suicide once. She was goin...        NaN         NaN
# 3   i cant think of one really...i think i may hav...        NaN         NaN
# 4   Only really one friend who doesn't fit into th...                    NaN
# ..                                                ...        ...         ...
# ...

# %% [markdown]
# ->NLP is used when there are certain features where we can't convert string to numeric by encoding. So to make model understand big texts we use NLP so our text can be feeded into model to make predictions.

# %% [markdown]
# ## NLP ROADMAP
#
# step 1: TEXT PREPROCESSING 1-> (Tokenization, Lemmatization,Stemming, stopwords)
# step 2: TEXT PREPROCESSING 2-> Vectorization (Bag of Words, TF-IDF,unigrams, bigrams)
# IN THIS WE ARE CLEANING THE TEXT (cleaning the input)
# step 3: TEXT PREPROCESSING 3->Advanced Vectorization (Word2vec, avgword2vec) vectors are used to create meaningfull insigths about the data or text which further can be used in machine learning models
